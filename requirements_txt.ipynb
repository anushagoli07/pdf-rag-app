# %%
# %%writefile requirements.txt
# streamlit
# langchain
# langchain-community
# chromadb
# sentence-transformers
# huggingface_hub
# pypdf
# Out:
# Writing requirements.txt

# %%
# !ls
# Out:
# requirements.txt  sample_data
