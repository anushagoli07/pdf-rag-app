# %%
# %%writefile requirements.txt
# streamlit
# langchain
# langchain-community
# langchain-text-splitters
# chromadb
# sentence-transformers
# huggingface_hub
# pypdf
# faiss-cpu
# Out:
# Overwriting requirements.txt
