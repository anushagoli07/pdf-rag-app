# %%
# %%writefile README.md
# # PDF Q&A RAG App
#
# Upload a PDF and ask questions using an LLM.
#
# Technologies:
# - LangChain
# - Streamlit
# - Hugging Face
# - Chroma vector database
# Out:
# Writing README.md
